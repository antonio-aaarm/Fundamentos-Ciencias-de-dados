# %% [markdown]
# pacotes

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Diagrama de dispersão

# %%
sns.scatterplot(x = 'total_bill', y= 'tip', data = tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = 'total_bill', y= 'tip', hue = 'day' , data = tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = 'total_bill', y= 'tip', hue = 'day' , data = tips, size = 'size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = 'total_bill', y= 'tip', hue = 'smoker' , data = tips, palette = 'magma')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.boxplot(y='tip', data = tips)
# Out:
# <Axes: ylabel='tip'>

# %%
sns.boxplot(y='tip', x= 'day',data = tips)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(y='tip', x= 'day',data = tips, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# Carregar conjunto de dados

# %%
crash = sns.load_dataset("car_crashes")

# %%
crash.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
sns.scatterplot(x='alcohol',  y = 'speeding', data = crash)
# Out:
# <Axes: xlabel='alcohol', ylabel='speeding'>

# %%
sns.barplot(x='sex', y = 'tip', data = tips)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.countplot(x = 'sex' , data = tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>
